# %% [markdown]
# # Plotting my results for DFT-D3 scans of motor 56

# %% [markdown]
# ## 1D scan using torsiondrive and RKS orbitals.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

name = "56sres"

dih = np.genfromtxt("/home/winter/onsager/tsqm/td/%s/energies.dat" %name, skip_header=0, skip_footer=0, usecols=0)
e = np.genfromtxt("/home/winter/onsager/tsqm/td/%s/energies.dat" %name, skip_header=0, skip_footer=0, usecols=1)

fig1, ax = plt.subplots(figsize=(10,10))
ax.plot(dih,e*628-np.min(e*628))   #converting hartree in raw data to kcal/mol
